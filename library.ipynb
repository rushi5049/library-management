# %%
book = dict()
print(book)
# Out:
# {}

# %%
def addbook(book, bookid, bookname, vol=2):
    book[bookid] = [bookname, vol]
    return
n = int(input("Enter nos of books to add"))
for i in range(0, n):
    bookid = int(input("Enter book id "))
    bookname = (input("Enter book name "))
    addbook(book, bookid, bookname)

print(book)
# Out:
# Enter nos of books to add 1
# Enter book id  1
# Enter book name  java
# {1: ['java', 2]}

# %%
borrower = dict()
def addborrower(borrower, borowerid=0):
    borrower[borrowerid] = 0
    return
    
n = int(input("enter nos of borrower to add:"))
for i in range (0, n):
    borrowerid = int(input("Enter borrower id:"))
    addborrower(borrower, borrowerid)
    
print(borrower)

nos_of_borrower = len(borrower.keys())
print(nos_of_borrower)

book_borrow =[]
for i in range(0 , nos_of_borrower):
    book_borrow.append(0)
book_borrow

nos_of_borrower = len(borrower.keys())
book_borrow = []
for i in range(nos_of_borrower):
    book_borrow.append(0)
print("initial borrow record:", book_borrow)
# Out:
# enter nos of borrower to add: 1
# Enter borrower id: 1
# {1: 0}
# 1
# initial borrow record: [0]

# %%
def issue_book():
    bookid = int(input("enter book id: "))
    if bookid in book.keys():
        avail_qty = book[bookid]
        print("Availablity:",avail_qty)
        if avail_qty[1]> 0:
            borrowerid = int(input("Enter borrower id :"))
            book[bookid][1] -= 1
            book_borrow[borrowerid - 1] =bookid 
            print("book issued succesfully !")
        else:
            print("book cannot be issued = no copies left")
    else:
        print("invalid book id ")

#issue a book 
issue_book()
print("updated borrow record:", book_borrow)
print("updated book:", book )

#print borrow list
# Out:
# enter book id:  1
# Availablity: ['java', 2]
# Enter borrower id : 1
# book issued succesfully !
# updated borrow record: [1]
# updated book: {1: ['java', 1]}
